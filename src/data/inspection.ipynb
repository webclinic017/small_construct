# %%
import pandas as pd

path = '/home/gordon/work/small_construct/data/raw/personal_assets/'
broker = pd.read_csv(path + 'chuckBrokerage_positions.csv')

broker.set_index('Description', inplace=True)
broker.fillna(0, inplace=True)
broker.columns
# Out:
# Index(['Symbol', 'Quantity', 'Price', 'Price Change $', 'Price Change %',
#        'Market Value', 'Day Change $', 'Day Change %', 'Cost Basis',
#        'Gain/Loss $', 'Gain/Loss %', 'Reinvest Dividends?', 'Capital Gains?',
#        '% Of Account', 'Dividend Yield', 'Last Dividend', 'Ex-Dividend Date',
#        'P/E Ratio', '52 Week Low', '52 Week High', 'Volume', 'Intrinsic Value',
#        'In The Money', 'Security Type'],
#       dtype='object')

# %%
broker = broker.drop(columns=['Price Change %', 'Reinvest Dividends?', 'Capital Gains?', 'Security Type', 'In The Money','Intrinsic Value'])
broker
# Out:
#                       $1,546.00       $15.00
# ARK GENOMIC REVOLUTION ETF                            $1,578.15       -$4.80
# ARK INNOVATION ETF                                    $1,349.60       -$0.90
# ARK NEXT GENERATION INTERNET ETF                      $1,525.90      -$13.50
# GRAYSCALE BITCOIN TR BTC                              $1,444.00      -$75.50
# CALL GROWGENERATION CORP $35 EXP 04/16/21             $1,140.00      -$80.00
# CALL INSEEGO CORP $15 EXP 03/19/21                      $400.00      -$55.00
# --                                                    $1,680.84        $0.00
# --                                                   $64,482.31   -$2,083.93
#
#                                                    Day Change %  Cost Basis  \
# Description
# APPLE INC                                                 -0.7%   $2,629.79
# BALLARD POWER SYS      F                                 +3.41%   $1,751.10
# ...
